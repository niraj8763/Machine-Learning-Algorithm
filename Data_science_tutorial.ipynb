# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/home/pi/Data_Science_Tutorial/pokemon.csv')
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        799 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 60.2+ KB

# %%
data.corr()
# Out:
#                    #        HP    Attack   Defense   Sp. Atk   Sp. Def  \
# #           1.000000  0.097712  0.102664  0.094691  0.089199  0.085596
# HP          0.097712  1.000000  0.422386  0.239622  0.362380  0.378718
# Attack      0.102664  0.422386  1.000000  0.438687  0.396362  0.263990
# Defense     0.094691  0.239622  0.438687  1.000000  0.223549  0.510747
# Sp. Atk     0.089199  0.362380  0.396362  0.223549  1.000000  0.506121
# Sp. Def     0.085596  0.378718  0.263990  0.510747  0.506121  1.000000
# Speed       0.012181  0.175952  0.381240  0.015227  0.473018  0.259133
# Generation  0.983428  0.058683  0.051451  0.042419  0.036437  0.028486
# Legendary   0.154336  0.273620  0.345408  0.246377  0.448907  0.363937
#
#                Speed  Generation  Legendary
# #           0.012181    0.983428   0.154336
# HP          0.175952    0.058683   0.273620
# Attack      0.381240    0.051451   0.345408
# Defense     0.015227    0.042419   0.246377
# ...

# %%
f,ax = plt.subplots(figsize=(18,18))
sns.heatmap(data.corr(),annot=True,linewidth=.5,fmt='.1f',ax=ax)
plt.show()

# %%
data.head(10)
# Out:
#     #              Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0   1         Bulbasaur  Grass  Poison  45      49       49       65       65
# 1   2           Ivysaur  Grass  Poison  60      62       63       80       80
# 2   3          Venusaur  Grass  Poison  80      82       83      100      100
# 3   4     Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4   5        Charmander   Fire     NaN  39      52       43       60       50
# 5   6        Charmeleon   Fire     NaN  58      64       58       80       65
# 6   7         Charizard   Fire  Flying  78      84       78      109       85
# 7   8  Mega Charizard X   Fire  Dragon  78     130      111      130       85
# 8   9  Mega Charizard Y   Fire  Flying  78     104       78      159      115
# 9  10          Squirtle  Water     NaN  44      48       65       50       64
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# ...

# %%
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
#  ## INTRODUCTION TO PYTHON
#  ### MATPLOTLIB

# %%
data.Speed.plot(kind='line',color = 'g',label='Speed',linewidth=1,alpha=0.5,grid=True,linestyle=':') 
data.Defense.plot(color = 'r',label = 'Defense',linewidth=1, alpha = 0.5,grid = True,linestyle = '-.')
plt.legend(loc='upper right')     
plt.xlabel('x axis')              
plt.ylabel('y axis')
plt.title('Line Plot')            
plt.show()

# %%
data.plot(kind='scatter', x='Attack', y='Defense',alpha = 0.5,color = 'red')
plt.xlabel('Attack')              
plt.ylabel('Defence')
plt.title('Attack Defense Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Attack Defense Scatter Plot')

# %%
data.Speed.plot(kind = 'hist',bins = 10,figsize = (12,12))
plt.show()

# %%
data.Speed.plot(kind = 'hist',bins = 50)
plt.clf()

# %% [markdown]
# ## PYTHON

# %%
dictionary = {'spain' : 'madrid','usa' : 'vegas'}
print(dictionary.keys())
print(dictionary.values())
# Out:
# dict_keys(['spain', 'usa'])
# dict_values(['madrid', 'vegas'])

# %%
dictionary['spain'] = "barcelona"    # update existing entry
print(dictionary)
dictionary['france'] = "paris"       # Add new entry
print(dictionary)
del dictionary['spain']              # remove entry with key 'spain'
print(dictionary)
print('france' in dictionary)        # check include or not
dictionary.clear()                   # remove all entries in dict
print(dictionary)
# Out:
# {'spain': 'barcelona', 'usa': 'vegas'}
# {'spain': 'barcelona', 'usa': 'vegas', 'france': 'paris'}
# {'usa': 'vegas', 'france': 'paris'}
# True
# {}

# %%
data = pd.read_csv('/home/pi/Data_Science_Tutorial/pokemon.csv')

# %%
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
series = data['Defense']
print(type(series))
data_frame = data[['Defense']]
print(type(data_frame))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
x = data['Defense']>200
data[x]
# Out:
#        #          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 224  225  Mega Steelix  Steel  Ground  75     125      230       55       95
# 230  231       Shuckle    Bug    Rock  20      10      230       10      230
# 333  334   Mega Aggron  Steel     NaN  70     140      230       60       80
#
#      Speed  Generation  Legendary
# 224     30           2      False
# 230      5           2      False
# 333     50           3      False

# %%
data[np.logical_and(data['Defense']>200,data['Attack']>100)]
# Out:
#        #          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 224  225  Mega Steelix  Steel  Ground  75     125      230       55       95
# 333  334   Mega Aggron  Steel     NaN  70     140      230       60       80
#
#      Speed  Generation  Legendary
# 224     30           2      False
# 333     50           3      False

# %%
data[(data['Defense']>200)&(data['Attack']>100)]
# Out:
#        #          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 224  225  Mega Steelix  Steel  Ground  75     125      230       55       95
# 333  334   Mega Aggron  Steel     NaN  70     140      230       60       80
#
#      Speed  Generation  Legendary
# 224     30           2      False
# 333     50           3      False

# %%
i = 0
while i !=5 :
    print('i is :',i)
    i +=1
print(i,'is equal to 5')
# Out:
# i is : 0
# i is : 1
# i is : 2
# i is : 3
# i is : 4
# 5 is equal to 5

# %%
lis = [1,2,3,4,5]
for i in lis :
    print('i is : ',i)
print('')
dictionary = {'spain':'madrid','france':'paris'}
for key,value in dictionary.items():
    print(key," : ",value)
print('')
for index,value in data[['Attack']][0:1].iterrows():
    print(index," : ",value)
# Out:
# i is :  1
# i is :  2
# i is :  3
# i is :  4
# i is :  5
#
# spain  :  madrid
# france  :  paris
#
# 0  :  Attack    49
# Name: 0, dtype: int64

# %%
def tuble_ex():
    t = (1,2,3)
    return t
a,b,c =tuble_ex()
print(a,b,c)
# Out:
# 1 2 3

# %%
x = 2,3 
def f():
    x =3
    return x
print(x)
print(f())
# Out:
# (2, 3)
# 3

# %%
x=50
def f():
    
    y = 2*x
    return y
print(f())
# Out:
# 100

# %%
import builtins
dir(builtins)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'RecursionError',
# ...

# %%
name = "ronaldo"
it = iter(name)
print(next(it))    # print next iteration
print(*it)         # print remaining iteration
# Out:
# r
# o n a l d o

# %%
list1 = [1,2,3,4]
list2 = [5,6,7,8]
z = zip(list1,list2)
print(z)
z_list = list(z)
print(z_list)
# Out:
# ...
# [(1, 5), (2, 6), (3, 7), (4, 8)]

# %%
un_zip = zip(*z_list)
un_list1,un_list2 = list(un_zip) # unzip returns tuble
print(un_list1)
print(un_list2)
print(type(un_list2))
# Out:
# (1, 2, 3, 4)
# (5, 6, 7, 8)
# <class 'tuple'>

# %%
s = lambda x : x**2
print(s(4))
# Out:
# 16

# %%
num = [1,2,3]
y = map(lambda X:X**2,num)
print(list(y))
# Out:
# [1, 4, 9]

# %%
n3 = [i+1 for i in num]
n3
# Out:
# [2, 3, 4]

# %%
num1 = [5,10,15,22,22]
num2 = [i**2 if i == 10 else i-5 if i < 22 else i+5 for i in num1]
print(num2)
# Out:
# [0, 100, 10, 27, 27]

# %%
threshold = sum(data.Speed)/len(data.Speed)
threshold
# Out:
# 68.2775

# %%
data["speed_level"] = ["high" if i > threshold else "low" for i in data.Speed]
data.loc[:10,["speed_level","Speed"]]
# Out:
#    speed_level  Speed
# 0          low     45
# 1          low     60
# 2         high     80
# 3         high     80
# 4          low     65
# 5         high     80
# 6         high    100
# 7         high    100
# 8         high    100
# 9          low     43
# 10         low     58

# %%
data = pd.read_csv('/home/pi/Data_Science_Tutorial/pokemon.csv')
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
data.tail()
# Out:
#        #            Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  796         Diancie     Rock  Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock  Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic  Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic   Dark  80     160       60      170
# 799  800       Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
data.shape
# Out:
# (800, 12)

# %%
data.info
# Out:
# <bound method DataFrame.info of        #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1       Bulbasaur    Grass  Poison  45      49       49       65
# 1      2         Ivysaur    Grass  Poison  60      62       63       80
# 2      3        Venusaur    Grass  Poison  80      82       83      100
# 3      4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4      5      Charmander     Fire     NaN  39      52       43       60
# ..   ...             ...      ...     ...  ..     ...      ...      ...
# 795  796         Diancie     Rock   Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 799  800       Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
print(data['Type 1'].value_counts(dropna=False))
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Ground       32
# Dragon       32
# Ghost        32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
data.describe()
# Out:
#               #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %%
data.boxplot(column="Attack",by = 'Legendary')

# %%
data_new = data.head()
data_new
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
melted = pd.melt(frame=data_new,id_vars='Name',value_vars = ['Attack','Defense'])

# %%
melted
# Out:
#             Name variable  value
# 0      Bulbasaur   Attack     49
# 1        Ivysaur   Attack     62
# 2       Venusaur   Attack     82
# 3  Mega Venusaur   Attack    100
# 4     Charmander   Attack     52
# 5      Bulbasaur  Defense     49
# 6        Ivysaur  Defense     63
# 7       Venusaur  Defense     83
# 8  Mega Venusaur  Defense    123
# 9     Charmander  Defense     43

# %%
melted.pivot(index='Name',columns='variable',values='value')
# Out:
# variable       Attack  Defense
# Name
# Bulbasaur          49       49
# Charmander         52       43
# Ivysaur            62       63
# Mega Venusaur     100      123
# Venusaur           82       83

# %%
data1 = data.head()
data2 = data.tail()
conc = pd.concat([data1,data1],axis=0,ignore_index = True)
conc
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
# 5  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 6  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 7  3       Venusaur  Grass  Poison  80      82       83      100      100
# 8  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 9  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# ...

# %%
data1 = data['Attack'].head()
data2 = data['Defense'].head()
conc_col = pd.concat([data1,data2],axis=1)
conc_col
# Out:
#    Attack  Defense
# 0      49       49
# 1      62       63
# 2      82       83
# 3     100      123
# 4      52       43

# %%
data.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
data['Type 1'] = data['Type 1'].astype('category')

# %%
data['Speed'] = data['Speed'].astype('float')

# %%
data.dtypes
# Out:
# #                int64
# Name            object
# Type 1        category
# Type 2          object
# HP               int64
# Attack           int64
# Defense          int64
# Sp. Atk          int64
# Sp. Def          int64
# Speed          float64
# Generation       int64
# Legendary         bool
# dtype: object

# %%
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0   45.0           1      False
# 1   60.0           1      False
# 2   80.0           1      False
# 3   80.0           1      False
# 4   65.0           1      False

# %%
data.dtypes
# Out:
# #                int64
# Name            object
# Type 1        category
# Type 2          object
# HP               int64
# Attack           int64
# Defense          int64
# Sp. Atk          int64
# Sp. Def          int64
# Speed          float64
# Generation       int64
# Legendary         bool
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        799 non-null    object
#  2   Type 1      800 non-null    category
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    float64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), category(1), float64(1), int64(7), object(2)
# memory usage: 58.3+ KB

# %%
data['Type 2'].value_counts(dropna=False)
# Out:
# NaN         386
# Flying       97
# Ground       35
# Poison       34
# Psychic      33
# Fighting     26
# Grass        25
# Fairy        23
# Steel        22
# Dark         20
# Dragon       18
# Ghost        14
# Rock         14
# Water        14
# Ice          14
# Fire         12
# Electric      6
# Normal        4
# Bug           3
# Name: Type 2, dtype: int64

# %%
data1  = data

# %%
data1['Type 2'].dropna(inplace=True)

# %%
assert 1==1

# %%
assert data['Type 2'].notnull().all()

# %%
data['Type 2'].fillna('empty',inplace =True)

# %%
data.isnull().sum()
# Out:
# #               0
# Name            1
# Type 1          0
# Type 2        386
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
data['Type 2'].fillna(method='ffill')
# Out:
# 0      Poison
# 1      Poison
# 2      Poison
# 3      Poison
# 6      Flying
#         ...
# 795     Fairy
# 796     Fairy
# 797     Ghost
# 798      Dark
# 799     Water
# Name: Type 2, Length: 414, dtype: object

# %%
data.isnull().sum()
# Out:
# #               0
# Name            1
# Type 1          0
# Type 2        386
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
len(data.values)
# Out:
# 800

# %%
country = ["Spain","France"]
population = ["11","12"]
list_label = ["country","population"]

# %%
list_col = [country,population]
zipped = list(zip(list_label,list_col))
data_dict = dict(zipped)
df = pd.DataFrame(data_dict)
df
# Out:
#   country population
# 0   Spain         11
# 1  France         12

# %%
zipped
# Out:
# [('country', ['Spain', 'France']), ('population', ['11', '12'])]

# %%
df['capital'] = ['madrid','india']

# %%
df
# Out:
#   country population capital
# 0   Spain         11  madrid
# 1  France         12   india

# %%
df['income'] = 0

# %%
df
# Out:
#   country population capital  income
# 0   Spain         11  madrid       0
# 1  France         12   india       0

# %%
data1  = data.loc [:,["Attack","Defense","Speed"]]
data1.plot()

# %%
data1.plot(subplots=True)
plt.show()

# %%
data1.plot(kind ='scatter', x= 'Attack',y= 'Defense')
plt.show()

# %%
data1.plot(kind = "hist",y = "Defense",bins = 50,range= (0,250))

# %%
fig,axes = plt.subplots(nrows=2,ncols=1)
data1.plot(kind='hist',y ='Defense',bins = 50,range = (0,250),normed=True,ax= axes[0])
data1.plot(kind = "hist",y = "Defense",bins = 50,range= (0,250),normed = True,ax = axes[1],cumulative = True)
plt.show()

# %%
data.describe()
# Out:
#               #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %%
time_list = ["1992-03-08","1992-04-12"]
print(type(time_list[1]))
# Out:
# <class 'str'>

# %%
time_list = ["1992-03-08","1992-04-12"]
print((time_list[1]))
# Out:
# 1992-04-12

# %%
datetime_object = pd.to_datetime(time_list)
print(type(datetime_object))
# Out:
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
datetime_object = pd.to_datetime(time_list)
datetime_object
# Out:
# DatetimeIndex(['1992-03-08', '1992-04-12'], dtype='datetime64[ns]', freq=None)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data2  = data.head()
date_list = ["1992-01-10","1992-02-10","1992-03-10","1993-03-15","1993-03-16"]
datetime_object = pd.to_datetime(date_list)
data2['date'] = datetime_object
data2 = data2.set_index('date')
data2
# Out:
#             #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# date
# 1992-01-10  1      Bulbasaur  Grass  Poison  45      49       49       65
# 1992-02-10  2        Ivysaur  Grass  Poison  60      62       63       80
# 1992-03-10  3       Venusaur  Grass  Poison  80      82       83      100
# 1993-03-15  4  Mega Venusaur  Grass  Poison  80     100      123      122
# 1993-03-16  5     Charmander   Fire     NaN  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary
# date
# 1992-01-10       65   45.0           1      False
# 1992-02-10       80   60.0           1      False
# 1992-03-10      100   80.0           1      False
# 1993-03-15      120   80.0           1      False
# 1993-03-16       50   65.0           1      False

# %%
print(data2.loc["1993-03-16"])
print(data2.loc["1992-03-10":"1993-03-16"])
# Out:
# #                      5
# Name          Charmander
# Type 1              Fire
# Type 2               NaN
# HP                    39
# Attack                52
# Defense               43
# Sp. Atk               60
# Sp. Def               50
# Speed                 65
# Generation             1
# Legendary          False
# Name: 1993-03-16 00:00:00, dtype: object
#             #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# date
# 1992-03-10  3       Venusaur  Grass  Poison  80      82       83      100
# 1993-03-15  4  Mega Venusaur  Grass  Poison  80     100      123      122
# 1993-03-16  5     Charmander   Fire     NaN  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary
# date
# 1992-03-10      100   80.0           1      False
# 1993-03-15      120   80.0           1      False
# 1993-03-16       50   65.0           1      False

# %%
data2.resample('A').mean()
# Out:
#               #         HP     Attack  Defense    Sp. Atk    Sp. Def  \
# date
# 1992-12-31  2.0  61.666667  64.333333     65.0  81.666667  81.666667
# 1993-12-31  4.5  59.500000  76.000000     83.0  91.000000  85.000000
#
#                 Speed  Generation  Legendary
# date
# 1992-12-31  61.666667         1.0      False
# 1993-12-31  72.500000         1.0      False

# %%
data2.resample('M').mean()
# Out:
#               #    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# date
# 1992-01-31  1.0  45.0    49.0     49.0     65.0     65.0   45.0         1.0
# 1992-02-29  2.0  60.0    62.0     63.0     80.0     80.0   60.0         1.0
# 1992-03-31  3.0  80.0    82.0     83.0    100.0    100.0   80.0         1.0
# 1992-04-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-05-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-06-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-07-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-08-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-09-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-10-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-11-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# ...

# %%
data2.resample("M").first().interpolate("ffill")
# Out:
#               #           Name Type 1  Type 2    HP  Attack  Defense  Sp. Atk  \
# date
# 1992-01-31  1.0      Bulbasaur  Grass  Poison  45.0    49.0     49.0     65.0
# 1992-02-29  2.0        Ivysaur  Grass  Poison  60.0    62.0     63.0     80.0
# 1992-03-31  3.0       Venusaur  Grass  Poison  80.0    82.0     83.0    100.0
# 1992-04-30  NaN            NaN  Grass     NaN   NaN     NaN      NaN      NaN
# 1992-05-31  NaN            NaN  Grass     NaN   NaN     NaN      NaN      NaN
# 1992-06-30  NaN            NaN  Grass     NaN   NaN     NaN      NaN      NaN
# 1992-07-31  NaN            NaN  Grass     NaN   NaN     NaN      NaN      NaN
# 1992-08-31  NaN            NaN  Grass     NaN   NaN     NaN      NaN      NaN
# 1992-09-30  NaN            NaN  Grass     NaN   NaN     NaN      NaN      NaN
# 1992-10-31  NaN            NaN  Grass     NaN   NaN     NaN      NaN      NaN
# 1992-11-30  NaN            NaN  Grass     NaN   NaN     NaN      NaN      NaN
# ...

# %%
data2.resample("M").mean().interpolate("linear")
# Out:
#                 #         HP  Attack  Defense  Sp. Atk  Sp. Def   Speed  \
# date
# 1992-01-31  1.000  45.000000    49.0     49.0    65.00    65.00  45.000
# 1992-02-29  2.000  60.000000    62.0     63.0    80.00    80.00  60.000
# 1992-03-31  3.000  80.000000    82.0     83.0   100.00   100.00  80.000
# 1992-04-30  3.125  78.291667    81.5     83.0    99.25    98.75  79.375
# 1992-05-31  3.250  76.583333    81.0     83.0    98.50    97.50  78.750
# 1992-06-30  3.375  74.875000    80.5     83.0    97.75    96.25  78.125
# 1992-07-31  3.500  73.166667    80.0     83.0    97.00    95.00  77.500
# 1992-08-31  3.625  71.458333    79.5     83.0    96.25    93.75  76.875
# 1992-09-30  3.750  69.750000    79.0     83.0    95.50    92.50  76.250
# 1992-10-31  3.875  68.041667    78.5     83.0    94.75    91.25  75.625
# 1992-11-30  4.000  66.333333    78.0     83.0    94.00    90.00  75.000
# 1992-12-31  4.125  64.625000    77.5     83.0    93.25    88.75  74.375
# ...

# %%
data = pd.read_csv('/home/pi/Data_Science_Tutorial/pokemon.csv')
data = data.set_index('#')
data.head()
# Out:
#             Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 1      Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 2        Ivysaur  Grass  Poison  60      62       63       80       80     60
# 3       Venusaur  Grass  Poison  80      82       83      100      100     80
# 4  Mega Venusaur  Grass  Poison  80     100      123      122      120     80
# 5     Charmander   Fire     NaN  39      52       43       60       50     65
#
#    Generation  Legendary
# #
# 1           1      False
# 2           1      False
# 3           1      False
# 4           1      False
# 5           1      False

# %%
data['HP'][1]
# Out:
# 45

# %%
data.HP[2]
# Out:
# 60

# %%
data.loc[3,['HP']]
# Out:
# HP    80
# Name: 3, dtype: object

# %%
data[['HP',"Attack"]]
# Out:
#      HP  Attack
# #
# 1    45      49
# 2    60      62
# 3    80      82
# 4    80     100
# 5    39      52
# ..   ..     ...
# 796  50     100
# 797  50     160
# 798  80     110
# 799  80     160
# 800  80     110
#
# [800 rows x 2 columns]

# %%
print(type(data['HP']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(type(data[['HP']]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data.loc[1:10,'HP':"Defense"]
# Out:
#     HP  Attack  Defense
# #
# 1   45      49       49
# 2   60      62       63
# 3   80      82       83
# 4   80     100      123
# 5   39      52       43
# 6   58      64       58
# 7   78      84       78
# 8   78     130      111
# 9   78     104       78
# 10  44      48       65

# %%
data.loc[10:1:-1,'HP':'Defense']
# Out:
#     HP  Attack  Defense
# #
# 10  44      48       65
# 9   78     104       78
# 8   78     130      111
# 7   78      84       78
# 6   58      64       58
# 5   39      52       43
# 4   80     100      123
# 3   80      82       83
# 2   60      62       63
# 1   45      49       49

# %%
data.loc[1:10,'Attack':]
# Out:
#     Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# 1       49       49       65       65     45           1      False
# 2       62       63       80       80     60           1      False
# 3       82       83      100      100     80           1      False
# 4      100      123      122      120     80           1      False
# 5       52       43       60       50     65           1      False
# 6       64       58       80       65     80           1      False
# 7       84       78      109       85    100           1      False
# 8      130      111      130       85    100           1      False
# 9      104       78      159      115    100           1      False
# 10      48       65       50       64     43           1      False

# %%
boolean = data.HP<200
data[boolean]
# Out:
#                Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1         Bulbasaur    Grass  Poison  45      49       49       65       65
# 2           Ivysaur    Grass  Poison  60      62       63       80       80
# 3          Venusaur    Grass  Poison  80      82       83      100      100
# 4     Mega Venusaur    Grass  Poison  80     100      123      122      120
# 5        Charmander     Fire     NaN  39      52       43       60       50
# ..              ...      ...     ...  ..     ...      ...      ...      ...
# 796         Diancie     Rock   Fairy  50     100      150      100      150
# 797    Mega Diancie     Rock   Fairy  50     160      110      160      110
# 798  Hoopa Confined  Psychic   Ghost  80     110       60      150      130
# 799   Hoopa Unbound  Psychic    Dark  80     160       60      170      130
# 800       Volcanion     Fire   Water  80     110      120      130       90
#
#      Speed  Generation  Legendary
# #
# ...

# %%
first_filter = data.HP>150
second_filter = data.Speed>35
data[first_filter&second_filter]
# Out:
#           Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 122    Chansey  Normal    NaN  250       5        5       35      105     50
# 262    Blissey  Normal    NaN  255      10       10       75      135     55
# 352    Wailord   Water    NaN  170      90       45       90       45     60
# 656  Alomomola   Water    NaN  165      75       80       40       45     65
#
#      Generation  Legendary
# #
# 122           1      False
# 262           2      False
# 352           3      False
# 656           5      False

# %%
len(data.HP[data.Speed<15])
# Out:
# 5

# %%
def div(n):
    return n/2
data.HP.apply(div)
# Out:
# #
# 1      22.5
# 2      30.0
# 3      40.0
# 4      40.0
# 5      19.5
#        ...
# 796    25.0
# 797    25.0
# 798    40.0
# 799    40.0
# 800    40.0
# Name: HP, Length: 800, dtype: float64

# %%
data.HP.apply(lambda n : n/2)
# Out:
# #
# 1      22.5
# 2      30.0
# 3      40.0
# 4      40.0
# 5      19.5
#        ...
# 796    25.0
# 797    25.0
# 798    40.0
# 799    40.0
# 800    40.0
# Name: HP, Length: 800, dtype: float64

# %%
data['total_power'] = data.Attack +data.Defense
data.head()
# Out:
#             Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 1      Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 2        Ivysaur  Grass  Poison  60      62       63       80       80     60
# 3       Venusaur  Grass  Poison  80      82       83      100      100     80
# 4  Mega Venusaur  Grass  Poison  80     100      123      122      120     80
# 5     Charmander   Fire     NaN  39      52       43       60       50     65
#
#    Generation  Legendary  total_power
# #
# 1           1      False           98
# 2           1      False          125
# 3           1      False          165
# 4           1      False          223
# 5           1      False           95

# %%
print(data.index.name)
# Out:
# #

# %%
data.index.name = 'Index Name'
data.head()
# Out:
#                      Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# Index Name
# 1               Bulbasaur  Grass  Poison  45      49       49       65
# 2                 Ivysaur  Grass  Poison  60      62       63       80
# 3                Venusaur  Grass  Poison  80      82       83      100
# 4           Mega Venusaur  Grass  Poison  80     100      123      122
# 5              Charmander   Fire     NaN  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary  total_power
# Index Name
# 1                65     45           1      False           98
# 2                80     60           1      False          125
# 3               100     80           1      False          165
# 4               120     80           1      False          223
# 5                50     65           1      False           95

# %%
data.head()
data3 = data.copy()
data3.index = range(100,900,1)
data3.head()
# Out:
#               Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 100      Bulbasaur  Grass  Poison  45      49       49       65       65
# 101        Ivysaur  Grass  Poison  60      62       63       80       80
# 102       Venusaur  Grass  Poison  80      82       83      100      100
# 103  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 104     Charmander   Fire     NaN  39      52       43       60       50
#
#      Speed  Generation  Legendary  total_power
# 100     45           1      False           98
# 101     60           1      False          125
# 102     80           1      False          165
# 103     80           1      False          223
# 104     65           1      False           95

# %%
data1 = pd.read_csv('/home/pi/Data_Science_Tutorial/pokemon.csv')
#data = data.set_index('#')
data1.head(100)
# Out:
#       #           Name  Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0     1      Bulbasaur   Grass  Poison   45      49       49       65
# 1     2        Ivysaur   Grass  Poison   60      62       63       80
# 2     3       Venusaur   Grass  Poison   80      82       83      100
# 3     4  Mega Venusaur   Grass  Poison   80     100      123      122
# 4     5     Charmander    Fire     NaN   39      52       43       60
# ..  ...            ...     ...     ...  ...     ...      ...      ...
# 95   96         Grimer  Poison     NaN   80      80       50       40
# 96   97            Muk  Poison     NaN  105     105       75       65
# 97   98       Shellder   Water     NaN   30      65      100       45
# 98   99       Cloyster   Water     Ice   50      95      180       85
# 99  100         Gastly   Ghost  Poison   30      35       30      100
#
#     Sp. Def  Speed  Generation  Legendary
# 0        65     45           1      False
# ...

# %%
dic = {"treatment":["A","A","B","B"],"gender":["F","M","F","M"],"response":[10,45,5,9],"age":[15,4,72,65]}

# %%
dic
# Out:
# {'treatment': ['A', 'A', 'B', 'B'],
#  'gender': ['F', 'M', 'F', 'M'],
#  'response': [10, 45, 5, 9],
#  'age': [15, 4, 72, 65]}

# %%
df = pd.DataFrame(dic)
df
# Out:
#   treatment gender  response  age
# 0         A      F        10   15
# 1         A      M        45    4
# 2         B      F         5   72
# 3         B      M         9   65

# %%
df.pivot(index="treatment",columns = "gender",values="response")
# Out:
# gender      F   M
# treatment
# A          10  45
# B           5   9

# %%
df1 = df.set_index(['treatment','gender'])
df1
# Out:
#                   response  age
# treatment gender
# A         F             10   15
#           M             45    4
# B         F              5   72
#           M              9   65

# %%
df1.unstack(level=0)
# Out:
#           response    age
# treatment        A  B   A   B
# gender
# F               10  5  15  72
# M               45  9   4  65

# %%
df1.unstack(level=1)
# Out:
#           response     age
# gender           F   M   F   M
# treatment
# A               10  45  15   4
# B                5   9  72  65

# %%
df2 = df1.swaplevel(0,1)
df2
# Out:
#                   response  age
# gender treatment
# F      A                10   15
# M      A                45    4
# F      B                 5   72
# M      B                 9   65

# %%
df
# Out:
#   treatment gender  response  age
# 0         A      F        10   15
# 1         A      M        45    4
# 2         B      F         5   72
# 3         B      M         9   65

# %%
pd.melt(df,id_vars="treatment",value_vars=["age","response"])
# Out:
#   treatment  variable  value
# 0         A       age     15
# 1         A       age      4
# 2         B       age     72
# 3         B       age     65
# 4         A  response     10
# 5         A  response     45
# 6         B  response      5
# 7         B  response      9

# %%
df.groupby('treatment').mean()
# Out:
#            response   age
# treatment
# A              27.5   9.5
# B               7.0  68.5

# %%
df.groupby('treatment').age.max()
# Out:
# treatment
# A    15
# B    72
# Name: age, dtype: int64

# %%
df.groupby("treatment")[["age","response"]].min()
# Out:
#            age  response
# treatment
# A            4        10
# B           65         5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   treatment  4 non-null      object
#  1   gender     4 non-null      object
#  2   response   4 non-null      int64
#  3   age        4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 160.0+ bytes
